# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You're an amazing initial draft generator. 
Your job is to take the user's topic of choice and run with. 

User's topic:
{topic}
"""

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You're going to be provided with a draft.
Your job is to reflect on it, provide feedback that is critical but constructive. 
It should address structure, clarity, strength of the argument and writing style. 

Here's the draft: 
{draft}
"""

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
You're tasked with revising a draft taking into account a reflection step
that is a constructive critique of the text. 

Original draft: 
{original_draft}

Reflection: 
{reflection}
""" 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media has become an integral part of daily life for billions of people worldwide. Platforms like Facebook, Twitter, Instagram, and TikTok have revolutionized how we communicate, share information, and consume news. However, with their growing influence, there has been increasing debate over whether these platforms should be regulated by the government. Advocates cite concerns over misinformation, privacy violations, and the platforms’ potential impact on democracy, while opponents argue such regulation could stifle free speech and innovation. This article examines both sides of the debate.
#
# The Case For Government Regulation
#
# 1. **Curbing Misinformation and Hate Speech**
#
#    One of the primary arguments for regulating social media platforms is the unchecked spread of misinformation and hate speech. False or misleading information about elections, health crises like COVID-19, and other critical issues can have serious, real-world consequences. Government oversight could help ensure that platforms take more responsibility for the content shared and promote accurate information.
#
# 2. **Protecting User Privacy**
#
#    Social media companies often collect vast amounts of personal data, which raises significant privacy concerns. By regulating these platforms, governments could enforce stricter privacy laws and protect users from data exploitation and breaches. Regulations like the European Union's General Data Protection Regulation (GDPR) serve as potential models for safeguarding digital privacy.
#
# 3. **Ensuring Fair Market Competition**
#
#    Many argue that major social media platforms operate as monopolies or oligopolies, which stifles competition and innovation. Government regulation could help break up these concentrations of power and encourage a more competitive marketplace that benefits consumers.
#
# 4. **Preserving Democratic Processes**
#
#    Social media has the power to influence public opinion and, by extension, democratic processes. Regulating these platforms could help prevent foreign interference in elections and ensure that political ads are transparent and truthful.
#
# The Case Against Government Regulation
#
# 1. **Risk of Censorship**
#
#    Critics of regulation often emphasize the danger of governmental overreach, where the suppression of speech becomes a tool for political purposes. They argue that entrusting the government to regulate speech could lead to censorship, limiting free expression and potentially targeting dissenting voices.
#
# 2. **Stifling Innovation**
#
#    The rapid advancements in social media have largely been driven by the private sector. Government regulation, critics argue, could stifle this innovation by imposing burdensome compliance requirements that small companies may struggle to meet, thereby maintaining the dominance of established players.
#
# 3. **Diverse Platforms, Diverse Policies**
#
#    Social media platforms are diverse, each with its unique features and community guidelines. A one-size-fits-all regulatory approach may not be practical or effective. The dynamic nature of social media requires adaptive policies that can be better tailored by the platforms themselves rather than a centralized regulatory body.
#
# 4. **Existing Self-Regulation Mechanisms**
#
#    Many social media companies have invested in fact-checking teams, content moderation technology, and partnerships with third-party organizations to address misinformation and harmful content. These self-regulation initiatives may be more agile and effective than external government intervention.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multi-faceted. While there are valid concerns on both sides of the debate, any move toward regulation must balance the need for oversight with the protection of free expression and innovation. As technology continues to evolve, ongoing dialogue among policymakers, tech companies, and the public will be essential in shaping the future of social media regulation.
#
# 🧠 Feedback:
#
# Here’s a balanced critique of your draft, organized by key areas. My goal is to highlight what’s working and suggest concrete ways to strengthen structure, clarity, argumentation, and style.
#
# 1. Structure
#   • Introduction
#     – Strengths: You open with context (rise of Facebook, Twitter, etc.) and lay out both sides.
#     – Suggestions:
#       • Thesis: State up front whether you lean toward regulation, self-regulation, or simply a middle path. That will guide your reader through the discussion.
#       • Roadmap: After your thesis, briefly preview the major headings you’ll cover (“We’ll first examine… then consider…”).
#   • Body Sections
#     – Strengths: Clear “For” vs. “Against” headings, each with numbered points.
#     – Suggestions:
#       • Parallelism: Each point should follow the same pattern—problem statement, evidence or example, possible counterargument.
#       • Depth: A couple of your points read like summary lists. Flesh them out with specific examples or statistics (e.g., “During the 2020 election, Platform X removed Y posts about Z, according to [source]”).
#       • Transitions: Use brief signposts at the start/end of each section to tie one point to the next (“Building on the threat of misinformation, privacy concerns also reveal…”).
#   • Conclusion
#     – Strengths: You restate the complexity and the need for balance and dialogue.
#     – Suggestions:
#       • Beyond Summary: Propose next steps or your own recommendation (e.g., “A multi-stakeholder council could oversee content standards…”).
#       • Call to Action: Invite policymakers, companies, or citizens to consider a specific framework or pilot program.
#
# 2. Clarity and Coherence
#   • Consistency of Terms: Make sure you define key terms early—what counts as “regulation”? Are you focusing on content moderation rules, data-privacy laws, antitrust measures, or all of the above?
#   • Avoid Generalities: Phrases like “burdensome compliance requirements” or “one-size-fits-all” are common critiques. Ground them in an example—perhaps a small startup forced to hire a dozen legal staff to meet EU-style regulations.
#   • Logical Flow: Sometimes the “Against” section feels like a mirror list rather than a rebuttal of specific “For” points. Consider cross-referencing (“While proponents note that GDPR protects privacy, critics argue that its strict consent rules delay innovation by weeks…”).
#
# 3. Strength of the Argument
#   • Evidence and Sources: Right now, the draft asserts concerns but doesn’t cite studies, surveys, or legal precedents. Even referencing one or two reports (e.g., Pew Research Center on disinformation) will lend authority.
#   • Nuance and Counterpoints: In “Protecting User Privacy,” acknowledge the counterargument that some data-use is essential for targeted moderation or ad-supported business models—and then explain how regulation could strike a balance.
#   • Weighing Trade-offs: Instead of presenting “For” and “Against” as equals, consider indicating which concerns pose more immediate harm (e.g., misinformation can cost lives) versus longer-term industry effects (e.g., slower feature rollouts).
#
# 4. Writing Style
#   • Tone: The draft is appropriately neutral, but tightening sentences will boost impact. For instance:
#      – Wordy: “Platforms like Facebook, Twitter, Instagram, and TikTok have revolutionized how we communicate, share information, and consume news.”
#      – Tighter: “Facebook, Twitter, Instagram, and TikTok have transformed communication, information-sharing, and news consumption.”
#   • Vary Sentence Length: Mix shorter, punchier sentences (“Regulation risks censorship.”) with longer ones to maintain reader engagement.
#   • Active Voice: Aim for active constructions (“Governments could enforce stricter privacy laws” rather than “stricter privacy laws could be enforced by governments”).
#   • Avoid List-Only Sections: Where possible, integrate bullet points into narrative paragraphs so the paper reads as a cohesive essay rather than a slide deck.
#
# 5. Overall Recommendations
#   1. Refine your thesis and roadmap in the introduction.
#   2. Bolster each argument with a brief case study, statistic, or quote.
#   3. Use transitions and cross-referencing to show how the “For” and “Against” points interact.
#   4. Conclude with a clear recommendation or framework, not just a restatement of complexity.
#   5. Tighten prose—lean, active, and varied in rhythm—to hold the reader’s interest.
#
# With these adjustments, your article will move from a solid outline to a compelling, authoritative discussion of social media regulation.
# ✍️ Revised:
#
# **Revised Draft: The Balancing Act of Regulating Social Media Platforms**
#
# **Introduction**
#
# In today's digital landscape, social media platforms such as Facebook, Twitter, Instagram, and TikTok have transformed how we communicate, share information, and consume news. As these platforms gain influence, the debate intensifies over whether government regulation is necessary. Proponents express concerns about misinformation, privacy breaches, and threats to democratic processes, while opponents see regulation as a potential curb on free speech and innovation. This article evaluates both sides, ultimately suggesting a balanced approach is crucial to navigate the complexities of regulation.
#
# **The Case For Government Regulation**
#
# 1. **Addressing Misinformation and Hate Speech**
#
#    Proponents of regulation argue for the necessity of government oversight to combat misinformation and hate speech. Unchecked, false or misleading information—about elections or health crises like COVID-19—can have dire consequences. For example, during the 2020 election, a social media platform reportedly removed thousands of misleading posts (source). Government intervention could compel platforms to promote more accurate information and be accountable for content dissemination.
#
# 2. **Enhancing User Privacy**
#
#    Social media platforms amass significant personal data, raising concerns about privacy. Through regulation, governments could enforce stricter privacy laws, akin to the EU's General Data Protection Regulation (GDPR), which shields users from data exploitation. Critics acknowledge that while data use is vital for targeted moderation, regulation can balance the need for privacy without stifling business models dependent on ad-revenue.
#
# 3. **Fostering Fair Market Competition**
#
#    Platforms often function as monopolies or oligopolies, inhibiting competition and innovation. Government intervention could dismantle these power concentrations, ensuring a competitive marketplace that favors consumers. By citing antitrust precedents, such as the EU’s actions against Google, proponents illustrate how regulation can inspire a more innovation-friendly environment.
#
# 4. **Safeguarding Democratic Processes**
#
#    Social media's capability to mold public opinion and influence democratic rituals is profound. Regulation could curb foreign election interference and mandate transparency in political advertising. This approach supports ensuring democratic integrity without compromising free expression.
#
# **The Case Against Government Regulation**
#
# 1. **Potential Censorship Risks**
#
#    Opponents voice concerns about government overreach, fearing regulation may lead to censorship that suppresses dissenting voices. They argue that entrusting speech regulation to the government might compromise free expression, as evidenced by historical instances where governments have censored critical media.
#
# 2. **Innovation Hurdles**
#
#    Innovation, primarily driven by the private sector, could be stunted by cumbersome regulatory compliance. Smaller startups could struggle under stringent rules, reinforcing the dominance of major players. For instance, the GDPR has led some startups to allocate significant resources to meet compliance (source), potentially stunting innovation.
#
# 3. **Diverse Approaches for Diverse Platforms**
#
#    Given each platform's distinct features and community guidelines, a one-size-fits-all regulatory framework may be dysfunctional. Platforms, with their unique adaptability, could better tailor flexible policies. The self-regulatory success stories from platforms like Twitter's Birdwatch, which harness community-driven fact-checking, showcase alternative models.
#
# 4. **Existing Self-Regulation Initiatives**
#
#    Social media companies have invested in internal measures such as fact-checking teams and content moderation technology to address misinformation. These measures could be more agile and effective compared to government intervention. Cross-referencing existing self-regulation initiatives with potential government policies reveals complex overlaps and gaps that require careful navigation.
#
# **Conclusion**
#
# The debate on government regulation of social media platforms is undeniably complex, with valid concerns on both ends. While government oversight offers solutions for misinformation and privacy, it also risks hampering innovation and free expression. Therefore, the path forward should involve a nuanced, multi-stakeholder approach that balances securing democratic values with fostering innovation. Policymakers, tech companies, and the public must collaborate to craft regulations that protect users while nurturing industry growth, perhaps through pilot programs assessing the impact of different regulatory models.
#
# **Overall Recommendations**
#
# - **Thesis Refinement:** Clearly articulate a stance in the introduction, blending the need for regulation with safeguards for free expression.
# - **Rich Examples:** Enrich arguments with case studies or statistics to add depth and authority.
# - **Logical Integration:** Use transitions to showcase how "For" and "Against" points interrelate.
# - **Conclude with Concrete Suggestions:** Offer actionable recommendations or frameworks beyond acknowledging complexity.
# - **Streamline Writing:** Employ active, concise sentences to maintain reader interest and engagement.
#
# By implementing these refinements, the article will progress from an initial outline to a thorough and authoritative discourse on regulating social media platforms.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for and Against Government Regulation of Social Media Platforms
#
# Introduction
#
# In the digital age, social media has become an integral part of daily life for billions of people worldwide. Platforms like Facebook, Twitter, Instagram, and TikTok have revolutionized how we communicate, share information, and consume news. However, with their growing influence, there has been increasing debate over whether these platforms should be regulated by the government. Advocates cite concerns over misinformation, privacy violations, and the platforms’ potential impact on democracy, while opponents argue such regulation could stifle free speech and innovation. This article examines both sides of the debate.
#
# The Case For Government Regulation
#
# 1. **Curbing Misinformation and Hate Speech**
#
#    One of the primary arguments for regulating social media platforms is the unchecked spread of misinformation and hate speech. False or misleading information about elections, health crises like COVID-19, and other critical issues can have serious, real-world consequences. Government oversight could help ensure that platforms take more responsibility for the content shared and promote accurate information.
#
# 2. **Protecting User Privacy**
#
#    Social media companies often collect vast amounts of personal data, which raises significant privacy concerns. By regulating these platforms, governments could enforce stricter privacy laws and protect users from data exploitation and breaches. Regulations like the European Union's General Data Protection Regulation (GDPR) serve as potential models for safeguarding digital privacy.
#
# 3. **Ensuring Fair Market Competition**
#
#    Many argue that major social media platforms operate as monopolies or oligopolies, which stifles competition and innovation. Government regulation could help break up these concentrations of power and encourage a more competitive marketplace that benefits consumers.
#
# 4. **Preserving Democratic Processes**
#
#    Social media has the power to influence public opinion and, by extension, democratic processes. Regulating these platforms could help prevent foreign interference in elections and ensure that political ads are transparent and truthful.
#
# The Case Against Government Regulation
#
# 1. **Risk of Censorship**
#
#    Critics of regulation often emphasize the danger of governmental overreach, where the suppression of speech becomes a tool for political purposes. They argue that entrusting the government to regulate speech could lead to censorship, limiting free expression and potentially targeting dissenting voices.
#
# 2. **Stifling Innovation**
#
#    The rapid advancements in social media have largely been driven by the private sector. Government regulation, critics argue, could stifle this innovation by imposing burdensome compliance requirements that small companies may struggle to meet, thereby maintaining the dominance of established players.
#
# 3. **Diverse Platforms, Diverse Policies**
#
#    Social media platforms are diverse, each with its unique features and community guidelines. A one-size-fits-all regulatory approach may not be practical or effective. The dynamic nature of social media requires adaptive policies that can be better tailored by the platforms themselves rather than a centralized regulatory body.
#
# 4. **Existing Self-Regulation Mechanisms**
#
#    Many social media companies have invested in fact-checking teams, content moderation technology, and partnerships with third-party organizations to address misinformation and harmful content. These self-regulation initiatives may be more agile and effective than external government intervention.
#
# Conclusion
#
# The question of whether social media platforms should be regulated by the government is complex and multi-faceted. While there are valid concerns on both sides of the debate, any move toward regulation must balance the need for oversight with the protection of free expression and innovation. As technology continues to evolve, ongoing dialogue among policymakers, tech companies, and the public will be essential in shaping the future of social media regulation.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Here’s a balanced critique of your draft, organized by key areas. My goal is to highlight what’s working and suggest concrete ways to strengthen structure, clarity, argumentation, and style.
#
# 1. Structure
#   • Introduction
#     – Strengths: You open with context (rise of Facebook, Twitter, etc.) and lay out both sides.
#     – Suggestions:
#       • Thesis: State up front whether you lean toward regulation, self-regulation, or simply a middle path. That will guide your reader through the discussion.
#       • Roadmap: After your thesis, briefly preview the major headings you’ll cover (“We’ll first examine… then consider…”).
#   • Body Sections
#     – Strengths: Clear “For” vs. “Against” headings, each with numbered points.
#     – Suggestions:
#       • Parallelism: Each point should follow the same pattern—problem statement, evidence or example, possible counterargument.
#       • Depth: A couple of your points read like summary lists. Flesh them out with specific examples or statistics (e.g., “During the 2020 election, Platform X removed Y posts about Z, according to [source]”).
#       • Transitions: Use brief signposts at the start/end of each section to tie one point to the next (“Building on the threat of misinformation, privacy concerns also reveal…”).
#   • Conclusion
#     – Strengths: You restate the complexity and the need for balance and dialogue.
#     – Suggestions:
#       • Beyond Summary: Propose next steps or your own recommendation (e.g., “A multi-stakeholder council could oversee content standards…”).
#       • Call to Action: Invite policymakers, companies, or citizens to consider a specific framework or pilot program.
#
# 2. Clarity and Coherence
#   • Consistency of Terms: Make sure you define key terms early—what counts as “regulation”? Are you focusing on content moderation rules, data-privacy laws, antitrust measures, or all of the above?
#   • Avoid Generalities: Phrases like “burdensome compliance requirements” or “one-size-fits-all” are common critiques. Ground them in an example—perhaps a small startup forced to hire a dozen legal staff to meet EU-style regulations.
#   • Logical Flow: Sometimes the “Against” section feels like a mirror list rather than a rebuttal of specific “For” points. Consider cross-referencing (“While proponents note that GDPR protects privacy, critics argue that its strict consent rules delay innovation by weeks…”).
#
# 3. Strength of the Argument
#   • Evidence and Sources: Right now, the draft asserts concerns but doesn’t cite studies, surveys, or legal precedents. Even referencing one or two reports (e.g., Pew Research Center on disinformation) will lend authority.
#   • Nuance and Counterpoints: In “Protecting User Privacy,” acknowledge the counterargument that some data-use is essential for targeted moderation or ad-supported business models—and then explain how regulation could strike a balance.
#   • Weighing Trade-offs: Instead of presenting “For” and “Against” as equals, consider indicating which concerns pose more immediate harm (e.g., misinformation can cost lives) versus longer-term industry effects (e.g., slower feature rollouts).
#
# 4. Writing Style
#   • Tone: The draft is appropriately neutral, but tightening sentences will boost impact. For instance:
#      – Wordy: “Platforms like Facebook, Twitter, Instagram, and TikTok have revolutionized how we communicate, share information, and consume news.”
#      – Tighter: “Facebook, Twitter, Instagram, and TikTok have transformed communication, information-sharing, and news consumption.”
#   • Vary Sentence Length: Mix shorter, punchier sentences (“Regulation risks censorship.”) with longer ones to maintain reader engagement.
#   • Active Voice: Aim for active constructions (“Governments could enforce stricter privacy laws” rather than “stricter privacy laws could be enforced by governments”).
#   • Avoid List-Only Sections: Where possible, integrate bullet points into narrative paragraphs so the paper reads as a cohesive essay rather than a slide deck.
#
# 5. Overall Recommendations
#   1. Refine your thesis and roadmap in the introduction.
#   2. Bolster each argument with a brief case study, statistic, or quote.
#   3. Use transitions and cross-referencing to show how the “For” and “Against” points interact.
#   4. Conclude with a clear recommendation or framework, not just a restatement of complexity.
#   5. Tighten prose—lean, active, and varied in rhythm—to hold the reader’s interest.
#
# With these adjustments, your article will move from a solid outline to a compelling, authoritative discussion of social media regulation.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Revised Draft: The Balancing Act of Regulating Social Media Platforms**
#
# **Introduction**
#
# In today's digital landscape, social media platforms such as Facebook, Twitter, Instagram, and TikTok have transformed how we communicate, share information, and consume news. As these platforms gain influence, the debate intensifies over whether government regulation is necessary. Proponents express concerns about misinformation, privacy breaches, and threats to democratic processes, while opponents see regulation as a potential curb on free speech and innovation. This article evaluates both sides, ultimately suggesting a balanced approach is crucial to navigate the complexities of regulation.
#
# **The Case For Government Regulation**
#
# 1. **Addressing Misinformation and Hate Speech**
#
#    Proponents of regulation argue for the necessity of government oversight to combat misinformation and hate speech. Unchecked, false or misleading information—about elections or health crises like COVID-19—can have dire consequences. For example, during the 2020 election, a social media platform reportedly removed thousands of misleading posts (source). Government intervention could compel platforms to promote more accurate information and be accountable for content dissemination.
#
# 2. **Enhancing User Privacy**
#
#    Social media platforms amass significant personal data, raising concerns about privacy. Through regulation, governments could enforce stricter privacy laws, akin to the EU's General Data Protection Regulation (GDPR), which shields users from data exploitation. Critics acknowledge that while data use is vital for targeted moderation, regulation can balance the need for privacy without stifling business models dependent on ad-revenue.
#
# 3. **Fostering Fair Market Competition**
#
#    Platforms often function as monopolies or oligopolies, inhibiting competition and innovation. Government intervention could dismantle these power concentrations, ensuring a competitive marketplace that favors consumers. By citing antitrust precedents, such as the EU’s actions against Google, proponents illustrate how regulation can inspire a more innovation-friendly environment.
#
# 4. **Safeguarding Democratic Processes**
#
#    Social media's capability to mold public opinion and influence democratic rituals is profound. Regulation could curb foreign election interference and mandate transparency in political advertising. This approach supports ensuring democratic integrity without compromising free expression.
#
# **The Case Against Government Regulation**
#
# 1. **Potential Censorship Risks**
#
#    Opponents voice concerns about government overreach, fearing regulation may lead to censorship that suppresses dissenting voices. They argue that entrusting speech regulation to the government might compromise free expression, as evidenced by historical instances where governments have censored critical media.
#
# 2. **Innovation Hurdles**
#
#    Innovation, primarily driven by the private sector, could be stunted by cumbersome regulatory compliance. Smaller startups could struggle under stringent rules, reinforcing the dominance of major players. For instance, the GDPR has led some startups to allocate significant resources to meet compliance (source), potentially stunting innovation.
#
# 3. **Diverse Approaches for Diverse Platforms**
#
#    Given each platform's distinct features and community guidelines, a one-size-fits-all regulatory framework may be dysfunctional. Platforms, with their unique adaptability, could better tailor flexible policies. The self-regulatory success stories from platforms like Twitter's Birdwatch, which harness community-driven fact-checking, showcase alternative models.
#
# 4. **Existing Self-Regulation Initiatives**
#
#    Social media companies have invested in internal measures such as fact-checking teams and content moderation technology to address misinformation. These measures could be more agile and effective compared to government intervention. Cross-referencing existing self-regulation initiatives with potential government policies reveals complex overlaps and gaps that require careful navigation.
#
# **Conclusion**
#
# The debate on government regulation of social media platforms is undeniably complex, with valid concerns on both ends. While government oversight offers solutions for misinformation and privacy, it also risks hampering innovation and free expression. Therefore, the path forward should involve a nuanced, multi-stakeholder approach that balances securing democratic values with fostering innovation. Policymakers, tech companies, and the public must collaborate to craft regulations that protect users while nurturing industry growth, perhaps through pilot programs assessing the impact of different regulatory models.
#
# **Overall Recommendations**
#
# - **Thesis Refinement:** Clearly articulate a stance in the introduction, blending the need for regulation with safeguards for free expression.
# - **Rich Examples:** Enrich arguments with case studies or statistics to add depth and authority.
# - **Logical Integration:** Use transitions to showcase how "For" and "Against" points interrelate.
# - **Conclude with Concrete Suggestions:** Offer actionable recommendations or frameworks beyond acknowledging complexity.
# - **Streamline Writing:** Employ active, concise sentences to maintain reader interest and engagement.
#
# By implementing these refinements, the article will progress from an initial outline to a thorough and authoritative discourse on regulating social media platforms.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
